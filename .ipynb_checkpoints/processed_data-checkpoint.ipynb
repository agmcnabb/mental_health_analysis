# %% [markdown]
# #### Opening processed_data from Alex

# %%
import pandas as pd
import os
import pathlib

import pickle

# %%
proce_data_dir = pathlib.Path().resolve()
print(proce_data_dir)
# Out:
# /home/nana/code/agmcnabb/mental_health_analysis

# %%
proce_data = os.path.join(proce_data_dir,'processed_data')

# %%
with open(proce_data, 'rb') as file:
    test = pickle.load(file)

# %%
test
# Out:
#          MCSID Cohort_Member_number_within_an_MCS_family  CM_Sex  \
# 0      M10002P           1st Cohort Member of the family    Male
# 1      M10007U           1st Cohort Member of the family    Male
# 2      M10015U           1st Cohort Member of the family  Female
# 3      M10016V           1st Cohort Member of the family    Male
# 4      M10018X           1st Cohort Member of the family  Female
# ...        ...                                       ...     ...
# 11854  M35868P           1st Cohort Member of the family    Male
# 11855  M35869Q           1st Cohort Member of the family  Female
# 11856  M35872K           1st Cohort Member of the family  Female
# 11857  M35873L           1st Cohort Member of the family  Female
# 11858  M35874M           1st Cohort Member of the family    Male
#
#       CM_DOB_(month)  CM_DOB_(year)  CM_Age_last_birthday  \
# 0              March           2001                    13
# 1            October           2000                    14
# ...
