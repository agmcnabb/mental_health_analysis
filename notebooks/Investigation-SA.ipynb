# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os
import pathlib

# %% [markdown]
# ## Import Raw Data

# %%
# relative path to data_raw
notebook_dir = pathlib.Path().resolve()
notebook_dir
# Out:
# PosixPath('/Users/samandrews/code/agmcnabb/mental_health_analysis')

# %%
raw_data_path_interview = os.path.join(notebook_dir, 'raw_data', 'sweep_6', 'UKDA-8156-tab', 'tab', 'mcs6_cm_interview.tab')
data = pd.read_csv(raw_data_path_interview, sep='\t',index_col='MCSID')

# %%
display(data.shape)
data.head()
# Out:
# (11859, 411)
#          FCNUM00  FCCSEX00  FCCDBM00  FCCDBY00  FCCAGE00  FCVERSF0  FCINTROA  \
# MCSID
# M10002P        1         1         3      2001        13       102         1
# M10007U        1         1        10      2000        14       102         1
# M10015U        1         2         5      2001        13       102         1
# M10016V        1         1        11      2000        14       102         1
# M10018X        1         2         7      2001        13       102         1
#
#          FCCHIC0A  FCCHIC0B  FCCHIC0C  ...  FCCARR02_TR3  FCCARR03_TR3  \
# MCSID                                  ...
# M10002P         1         0         0  ...            -1            -1
# M10007U         1         0         0  ...            -1            -1
# M10015U         1         0         0  ...            -1            -1
# M10016V         1         0         0  ...           344            -1
# M10018X         1         0         0  ...            -1            -1
#
# ...
